# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ### 모델 로드

# %%
model = YOLO("../weights/yolov8n-face-lindevs.pt")

# %% [markdown]
# ### 이미지 읽기

# %%
img = cv2.imread("../images/test16.jpg")

# %% [markdown]
# ### Detection 시간 측정

# %%
start = time.perf_counter()
results = model(img,verbose=False)
end = time.perf_counter()
elapsed = end-start

# %% [markdown]
# ### Bounding Box 시각화

# %%
boxes = results[0].boxes
for box in boxes:

    x1, y1, x2, y2 = map(int, box.xyxy[0])

    cv2.rectangle(
        img,
        (x1, y1),
        (x2, y2),
        (0, 255, 0),
        2
    )

# %% [markdown]
# ### 이미지 출력

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12,12))
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Detection 시간 및 얼굴 수 결과 출력

# %%
print(f"검출된 얼굴 수 : {len(boxes)}")
print(f"검출 시간 : {elapsed*1000:.2f} ms ({elapsed:.2f} sec))")
# Out:
# 검출된 얼굴 수 : 2
# 검출 시간 : 74.00 ms (0.07 sec))
